# %%
#Import the Libraries and dependencies 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random 
import seaborn as sns
from fbprophet import Prophet
from datetime import datetime

# %%
dataset_df = pd.read_csv('atlantic.csv',error_bad_lines=False)

# %%
dataset_df.drop(['ID','Name', 'Time' , 'Event' , 'Latitude', 'Maximum Wind', 'Minimum Pressure','Low Wind SW', 'Low Wind NW', 'Moderate Wind NE', 'Moderate Wind SE', 'Moderate Wind SW', 'Moderate Wind NW' , 'High Wind NE', 'High Wind SE', 'High Wind SW', 'High Wind NW' ,'Longitude' , 'Low Wind NE' ,'Low Wind SE'], inplace=True ,axis = 1)

# %%
dataset_df['Date']=pd.to_datetime(dataset_df['Date'].astype(str), format='%Y/%m/%d')
dataset_df['Date'] = dataset_df["Date"].apply(str)

type(dataset_df["Date"][0])
# Out:
# str

# %%
dataset_df
# Out:
#                            Date Status
# Date
# 1851-06-25  1851-06-25 00:00:00     HU
# 1851-06-25  1851-06-25 00:00:00     HU
# 1851-06-25  1851-06-25 00:00:00     HU
# 1851-06-25  1851-06-25 00:00:00     HU
# 1851-06-25  1851-06-25 00:00:00     HU
# ...                         ...    ...
# 2015-11-12  2015-11-12 00:00:00     EX
# 2015-11-12  2015-11-12 00:00:00     EX
# 2015-11-13  2015-11-13 00:00:00     EX
# 2015-11-13  2015-11-13 00:00:00     EX
# 2015-11-13  2015-11-13 00:00:00     EX
#
# [49105 rows x 2 columns]

# %%
dataset_df['Status'].value_counts()
type(dataset_df["Date"][0])
# Out:
# str

# %%
plt.figure(figsize=(15,10))
sns.countplot(y = 'Status' , data = dataset_df, order = dataset_df['Status'].value_counts().iloc[:15].index)

# %%
sns.countplot(x = 'Status' ,data = dataset_df)

# %%
dataset_df.index = pd.DatetimeIndex(dataset_df.Date)

type(dataset_df["Date"][0])
# Out:
# str

# %%
dataset_df.resample('M').size()

type(dataset_df["Date"][0])
# Out:
# str

# %%
plt.plot(dataset_df.resample('Y').size())

# %%
dataset_prophet = dataset_df.resample('M').size().reset_index()

type(dataset_df["Date"][0])
# Out:
# str

# %%
dataset_prophet
# Out:
#            Date    0
# 0    1851-06-30   14
# 1    1851-07-31    2
# 2    1851-08-31   49
# 3    1851-09-30   16
# 4    1851-10-31   17
# ...         ...  ...
# 1969 2015-07-31   15
# 1970 2015-08-31   55
# 1971 2015-09-30  140
# 1972 2015-10-31   59
# 1973 2015-11-30   20
#
# [1974 rows x 2 columns]

# %%
dataset_prophet.columns = ['Date','Status']
type(dataset_df["Date"][0])
# Out:
# str

# %%
dataset_prophet
# Out:
#            Date  Status
# 0    1851-06-30      14
# 1    1851-07-31       2
# 2    1851-08-31      49
# 3    1851-09-30      16
# 4    1851-10-31      17
# ...         ...     ...
# 1969 2015-07-31      15
# 1970 2015-08-31      55
# 1971 2015-09-30     140
# 1972 2015-10-31      59
# 1973 2015-11-30      20
#
# [1974 rows x 2 columns]

# %%
dataset_prophet = pd.DataFrame(dataset_prophet)

# %%
dataset_prophet
# Out:
#            Date  Status
# 0    1851-06-30      14
# 1    1851-07-31       2
# 2    1851-08-31      49
# 3    1851-09-30      16
# 4    1851-10-31      17
# ...         ...     ...
# 1969 2015-07-31      15
# 1970 2015-08-31      55
# 1971 2015-09-30     140
# 1972 2015-10-31      59
# 1973 2015-11-30      20
#
# [1974 rows x 2 columns]

# %%
dataset_prophet.columns
# Out:
# Index(['Date', 'Status'], dtype='object')

# %%
dataset_prophet_final = dataset_prophet.rename(columns = {'Date': 'ds', 'Status':'y'})

# %%
dataset_prophet_final
# Out:
#              ds    y
# 0    1851-06-30   14
# 1    1851-07-31    2
# 2    1851-08-31   49
# 3    1851-09-30   16
# 4    1851-10-31   17
# ...         ...  ...
# 1969 2015-07-31   15
# 1970 2015-08-31   55
# 1971 2015-09-30  140
# 1972 2015-10-31   59
# 1973 2015-11-30   20
#
# [1974 rows x 2 columns]

# %%
m = Prophet()

m.fit(dataset_prophet_final)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)

# forecast["ds"] = forecast["ds"].apply(str)
# dataset_df['Date'] = dataset_df["Date"].apply(str)

# %%
forecast
# Out:
#              ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0    1851-06-30   6.357699  -38.496580   34.086180     6.357699     6.357699
# 1    1851-07-31   6.385261  -32.316576   40.471005     6.385261     6.385261
# 2    1851-08-31   6.412823   11.398238   85.427479     6.412823     6.412823
# 3    1851-09-30   6.439496   51.615222  128.188236     6.439496     6.439496
# 4    1851-10-31   6.467058    4.152201   78.589470     6.467058     6.467058
# ...         ...        ...         ...         ...          ...          ...
# 2334 2016-11-25  40.370644  -35.822802   40.246874    40.370644    40.370644
# 2335 2016-11-26  40.371203  -30.574533   41.898536    40.371203    40.371203
# 2336 2016-11-27  40.371761  -23.578019   50.502620    40.371761    40.371761
# 2337 2016-11-28  40.372319  -17.627526   53.694637    40.372319    40.372319
# 2338 2016-11-29  40.372878  -10.564798   61.646814    40.372878    40.372878
#
#       additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0          -8.057367             -8.057367             -8.057367  -8.057367
# 1          -3.081964             -3.081964             -3.081964  -3.081964
# 2          41.255690             41.255690             41.255690  41.255690
# 3          83.330606             83.330606             83.330606  83.330606
# 4          37.630355             37.630355             37.630355  37.630355
# ...              ...                   ...                   ...        ...
# 2334      -39.134307            -39.134307            -39.134307 -39.134307
# 2335      -34.279105            -34.279105            -34.279105 -34.279105
# 2336      -28.582443            -28.582443            -28.582443 -28.582443
# 2337      -22.239014            -22.239014            -22.239014 -22.239014
# 2338      -15.459473            -15.459473            -15.459473 -15.459473
#
#       yearly_lower  yearly_upper  multiplicative_terms  \
# 0        -8.057367     -8.057367                   0.0
# 1        -3.081964     -3.081964                   0.0
# 2        41.255690     41.255690                   0.0
# 3        83.330606     83.330606                   0.0
# 4        37.630355     37.630355                   0.0
# ...            ...           ...                   ...
# 2334    -39.134307    -39.134307                   0.0
# 2335    -34.279105    -34.279105                   0.0
# 2336    -28.582443    -28.582443                   0.0
# 2337    -22.239014    -22.239014                   0.0
# 2338    -15.459473    -15.459473                   0.0
#
#       multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 0                            0.0                         0.0  -1.699668
# 1                            0.0                         0.0   3.303297
# 2                            0.0                         0.0  47.668513
# 3                            0.0                         0.0  89.770102
# 4                            0.0                         0.0  44.097413
# ...                          ...                         ...        ...
# 2334                         0.0                         0.0   1.236337
# 2335                         0.0                         0.0   6.092098
# 2336                         0.0                         0.0  11.789318
# 2337                         0.0                         0.0  18.133305
# 2338                         0.0                         0.0  24.913404
#
# [2339 rows x 16 columns]

# %%
pd.plotting.register_matplotlib_converters()
m.plot(forecast,  xlabel='Date', ylabel='Events')

# type(forecast["ds"][0])

# %%
figure3 = m.plot_components(forecast)
